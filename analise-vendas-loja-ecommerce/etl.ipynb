# %% [markdown]
# ## <span style="color:blue">Notebook de Análises</span>
#
# Este notebook tem por finalidade demonstrar o funcionamento do projeto:
#
# - Geração do Dataset
# - Transformação, limpeza e enriquecimento do dados
# - Criação de gráficos pra melhor visualização dos resultados

# %% [markdown]
# ### Geração do dataset
# Import da biblioteca criada pra geração dos dados aleatórios, transformação e carga dos dados gerados, na desmontração foram gerados 1000 dados de vendas.

# %%
from dados import bronze, silver, gold
bronze.gerar_dados(10000)
# Out:
#       cliente         produto preco                  categoria  quantidade  \
# 0        8707    home theater                TV, Áudio e Vídeo           5
# 1        5173        notebook  4000  Informática e Periféricos           1
# 2        9695    home theater                TV, Áudio e Vídeo           5
# 3        2916  fone de ouvido   200   Smartphones e Acessórios           5
# 4        5761         monitor  1500  Informática e Periféricos           3
# ...       ...             ...   ...                        ...         ...
# 9995     6701  fone de ouvido   200   Smartphones e Acessórios           1
# 9996     7172           fogao  1500           Eletrodomésticos           2
# 9997     2100     micro-ondas                 Eletrodomésticos           5
# 9998     4862        smart tv  4000          TV, Áudio e Vídeo           1
# 9999     5583        soundbar  1000          TV, Áudio e Vídeo           5
#
#             data
# 0     2024-07-08
# 1     2024-02-22
# 2     2024-12-29
# 3     2025-12-17
# 4     2025-03-06
# ...          ...
# 9995  2025-09-25
# 9996  2025-06-17
# 9997  2024-07-13
# 9998  2025-06-12
# 9999  2025-10-07
#
# [10000 rows x 6 columns]

# %% [markdown]
# ### Tranformação, limpeza e enriquecimento dos dados.
# - Remoção de valores nulos
# - Organização das datas
# - Remoção de duplicatas se houver
# - Padronização das datas conforme a norma nacional NBR 5892:2019 "dd/mm/yyyy”
# - Calcular o valor total da venda “Preço x Quantidade"

# %%
dados_vendas_silver = silver.transformar_dados(caminho_entrada="output/dados_bronze.csv", 
                                               caminho_saida="output/dados_silver.csv")
dados_vendas_silver.head()
# Out:
# Registros originais: 10000
# A quantidade atual de registros é 7654, foram removidos 2346 por conterem valores nulos.
# A quantidade atual de registros é 7654 após a remoção de duplicatas.
# As datas foram padronizadas para o formato dd/mm/yyyy.
# As datas foram ordenadas em ordem decrescente.
# A coluna 'valor_total' foi adicionada ao DataFrame.
#       cliente     produto   preco                  categoria  quantidade  \
# 162      6832    notebook  4000.0  Informática e Periféricos           3
# 5867     3244  carregador   100.0   Smartphones e Acessórios           2
# 8389     2441       fogao  1500.0           Eletrodomésticos           1
# 6131     8759       fogao  1500.0           Eletrodomésticos           5
# 5939     2741       fogao  1500.0           Eletrodomésticos           2
#
#             data  valor_total
# 162   31/12/2025      12000.0
# 5867  31/12/2025        200.0
# 8389  31/12/2025       1500.0
# 6131  31/12/2025       7500.0
# 5939  31/12/2025       3000.0

# %% [markdown]
# ### Carregamento dos dados
# Carregamento dos dados da tabela silver pra tabela gold.

# %%
dados_vendas_gold = gold.carregar_dados(caminho_entrada="output/dados_silver.csv", 
                                        caminho_saida="output/dados_gold.csv")
dados_vendas_gold.head()
# Out:
# Dados carregados com sucesso. Aqui estão as primeiras linhas:
#    cliente     produto   preco                  categoria  quantidade  \
# 0     6832    notebook  4000.0  Informática e Periféricos           3
# 1     3244  carregador   100.0   Smartphones e Acessórios           2
# 2     2441       fogao  1500.0           Eletrodomésticos           1
# 3     8759       fogao  1500.0           Eletrodomésticos           5
# 4     2741       fogao  1500.0           Eletrodomésticos           2
#
#          data  valor_total
# 0  31/12/2025      12000.0
# 1  31/12/2025        200.0
# 2  31/12/2025       1500.0
# 3  31/12/2025       7500.0
# 4  31/12/2025       3000.0
